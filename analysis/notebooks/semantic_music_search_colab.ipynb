# %% [markdown]
# # KEXP Music Semantic Search - Colab Processing
#
# This notebook processes the KEXP music database to create semantic embeddings for music search.
#
# **Output**: Enhanced SQLite database with:
# - Vector embeddings (sqlite-vec)
# - FTS5 keyword index
# - Ready for hybrid semantic + keyword search
#
# **Prerequisites**:
# - music_kb.sqlite database
# - Google Colab (free tier works fine)
# - ~30 minutes processing time

# %% [markdown]
# ## 1. Setup & Installation

# %%
# Install required packages
# !pip install -q sentence-transformers sqlite-vec torch pandas numpy tqdm

# %%
# Check GPU availability
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
if device == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## 2. Upload Database
#
# Choose one method:
# - **Option A**: Mount Google Drive (if database is already in Drive)
# - **Option B**: Direct upload (if database is local)

# %%
# Option A: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Update this path to your database location
DB_PATH = '/content/drive/MyDrive/music_kb.sqlite'

# %%
# Option B: Direct upload
# Uncomment if you want to upload directly instead
# from google.colab import files
# uploaded = files.upload()
# DB_PATH = list(uploaded.keys())[0]
